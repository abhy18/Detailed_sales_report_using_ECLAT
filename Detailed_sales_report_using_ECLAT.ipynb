# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/Detailed-Sales-Report.xlsx',header= None)
df
# Out:
#                          0            1            2   \
# 0     Detailed Sales Report          NaN          NaN
# 1                   Sr. No.         Date  Invoice No.
# 2                         1  11 Aug 2023        INV11
# 3                         2  11 Aug 2023        INV11
# 4                         3  11 Aug 2023        INV12
# ...                     ...          ...          ...
# 3376                   3375  08 Sep 2023      INV2260
# 3377                   3376  08 Sep 2023      INV2260
# 3378                   3377  08 Sep 2023      INV2261
# 3379                   3378  08 Sep 2023      INV2262
# 3380                   3379  08 Sep 2023      INV2263
#
#                               3                 4             5         6   \
# 0                            NaN               NaN           NaN       NaN
# 1                    Client Name      Product Name  Product Code  Quantity
# 2                          Ashiq         Maaza big           NaN         1
# 3                          Ashiq  Watermelon Juice             1         2
# 4                          Ashiq         Maaza big           NaN         1
# ...                          ...               ...           ...       ...
# 3376                      Swetha         Rose milk           NaN         1
# 3377                      Swetha     Musambi juice           NaN         1
# 3378                    Akshitha         Rose milk           NaN         3
# 3379                     Moshika     Bread omlette           NaN         1
# 3380  Nagalakshmi Avinashilingam         Veg momos           NaN         1
#
#         7         8        9    10                11
# 0      NaN       NaN      NaN  NaN               NaN
# 1     Rate  Discount  Taxable  Tax  Amount After Tax
# 2       20         0       20    0                20
# 3       40         0       80    0                80
# 4       20         0       20    0                20
# ...    ...       ...      ...  ...               ...
# 3376    45         0       45    0                45
# 3377    50         0       50    0                50
# 3378    45         0      135    0               135
# 3379    60         0       60    0                60
# 3380    80         0       80    0                80
#
# [3381 rows x 12 columns]

# %%
df= df.iloc[2:,[2,4]]
df.columns = ['Invoice','Item']
df
# Out:
#       Invoice                 Item
# 2       INV11            Maaza big
# 3       INV11     Watermelon Juice
# 4       INV12            Maaza big
# 5       INV13      Muskmelon Juice
# 6       INV13  Chocolate milkshake
# ...       ...                  ...
# 3376  INV2260            Rose milk
# 3377  INV2260        Musambi juice
# 3378  INV2261            Rose milk
# 3379  INV2262        Bread omlette
# 3380  INV2263            Veg momos
#
# [3379 rows x 2 columns]

# %%
  grp = df.groupby('Invoice')['Item'].apply(list).reset_index()
  expand = grp['Item'].apply(pd.Series)
  expand
# Out:
#                        0                 1                 2  \
# 0       Watermelon Juice               NaN               NaN
# 1     Water bottle small               NaN               NaN
# 2        Muskmelon Juice               NaN               NaN
# 3            Lemon juice    Oreo milkshake  Blueberry Mojito
# 4              Coco cola               NaN               NaN
# ...                  ...               ...               ...
# 2199      Chicken burger               NaN               NaN
# 2200          Veg burger  Blueberry Mojito               NaN
# 2201    Blueberry Mojito               NaN               NaN
# 2202          Egg Maggie               NaN               NaN
# 2203      Chicken Maggie     Musambi juice               NaN
#
#                             3                4    5    6    7    8
# 0                         NaN              NaN  NaN  NaN  NaN  NaN
# 1                         NaN              NaN  NaN  NaN  NaN  NaN
# 2                         NaN              NaN  NaN  NaN  NaN  NaN
# 3     Butter scotch milkshake  Muskmelon Juice  NaN  NaN  NaN  NaN
# 4                         NaN              NaN  NaN  NaN  NaN  NaN
# ...                       ...              ...  ...  ...  ...  ...
# 2199                      NaN              NaN  NaN  NaN  NaN  NaN
# 2200                      NaN              NaN  NaN  NaN  NaN  NaN
# 2201                      NaN              NaN  NaN  NaN  NaN  NaN
# 2202                      NaN              NaN  NaN  NaN  NaN  NaN
# 2203                      NaN              NaN  NaN  NaN  NaN  NaN
#
# [2204 rows x 9 columns]

# %%
# !pip install pyECLAT
# Out:
# Collecting pyECLAT
#   Downloading pyECLAT-1.0.2-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from pyECLAT) (2.0.3)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.10/dist-packages (from pyECLAT) (1.25.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from pyECLAT) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->pyECLAT) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->pyECLAT) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->pyECLAT) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->pyECLAT) (1.16.0)
# Installing collected packages: pyECLAT
# Successfully installed pyECLAT-1.0.2

# %%
from pyECLAT import ECLAT
ec = ECLAT(data=expand, verbose=True)
# Out:
# 100%|██████████| 118/118 [00:00<00:00, 220.95it/s]
# 100%|██████████| 118/118 [00:00<00:00, 6372.43it/s]
# 100%|██████████| 118/118 [00:00<00:00, 2359.19it/s]

# %%
ec.uniq_
# Out:
# ['Belgium chocolate',
#  'Maaza small',
#  'Buffalo wings',
#  'Strawberry milkshake',
#  'Crispy chicken wings',
#  'Icone Belgian Chocolate',
#  'Club Sandwich',
#  'Vannila cup',
#  'Chicken Bread Omlette',
#  'Veg burger',
#  'Trio stick',
#  'Oreo milkshake',
#  'Chicken sandwich',
#  'Bites Chocolate',
#  'Cheese Maggie',
#  'Cold coffee',
#  'Watermelon Juice',
#  'Cheese corn nuggets',
#  'Blackcurrant Milkshake',
#  'Fish fingers',
#  'Lemon rice',
#  'Veg Cheese Sandwich',
#  'Chicken popcorn',
#  'Blue curacao mojito',
#  'Paneer wrap',
#  'Chocobar mini',
#  'Butter scotch milkshake',
#  'Crispy chicken wrap',
#  'French fries',
#  'Spicy veg burger',
#  'Plain Maggie',
#  'Butterscotch mojito',
#  'Butterscotch Milkshake',
#  'Chicken wrap',
#  'Icone chocolate',
#  'Lime mint mojito',
#  'Paneer Sandwich',
#  'Spicy chicken wrap',
#  'Curd rice',
#  'Peri peri Maggie',
#  'Crispy fried corn',
#  'Brownie',
#  'Vannila cup big',
#  'Veg sandwich',
#  'Spicy chicken burger',
#  'Fanta',
#  'Mixed fruit minute maid',
#  'Offer cold coffee',
#  'Icone blackcurrant',
#  'Elaneer payasam',
#  'Masala Omlette',
#  'Hariyali Chicken Tikka',
#  'Crispy chicken burger',
#  'Veg Maagi',
#  'Peri Peri French Fries',
#  'Egg Sandwich',
#  'Egg Maggie',
#  'Blackcurrant mojito',
#  'Water bottle small',
#  'Crispy wings',
#  'Casata',
#  'Spicy chicken sandwich',
#  'Brownie Milkshake',
#  'Lemon juice',
#  'Chicken momos',
#  'Lime mojito',
#  'Double chocolate cone',
#  'Icone Chocolate Mini',
#  'Coco cola',
#  'Muskmelon Juice',
#  'Classic chicken burger',
#  'Smiles',
#  'Spicy veg sandwich',
#  'Chicken Maggie',
#  nan,
#  'Classic Veg Burger',
#  'Smoky wings',
#  'Chocolate cup',
#  'Bread omlette',
#  'Pulpy orange',
#  'Sweet corn Maggie',
#  'Choco lava cake',
#  'Sports limca',
#  'Brownie with ice cream',
#  'Cotton Candy',
#  'Maaza big',
#  'Blackcurrent i cone',
#  'Choco Bar',
#  'Veg momos',
#  'Corn poppers',
#  'Spicy veg wrap',
#  'Musambi juice',
#  'Chicken Briyani',
#  'Parcel charges',
#  'Sharjah Shake',
#  'Spicy Veg Cheese Burger',
#  'Potato wedges',
#  'Blueberry Mojito',
#  'Chocolate milkshake',
#  'Icone butterscotch',
#  'Veg wrap',
#  'Chicken nuggets',
#  'Sprite',
#  'Veg Maggie',
#  'Paneer Burger',
#  'Lemon Soda',
#  'Cold boost',
#  'Rose milk',
#  'Likstick',
#  'Vannila milkshake',
#  'Crispy chicken sandwich',
#  'Watermelon Mojito',
#  'Lime soda',
#  'Peri Peri Cheese Maggie',
#  'Butter Scotch Mojito',
#  'Chicken burger',
#  'Chocobar big',
#  'Parcel charges big',
#  'Basundhi']

# %%
indexs , support = ec.fit(min_support=.02,min_combination=1,max_combination=3,separator = ' & ',verbose = True)
# Out:
# Combination 1 by 1
# 22it [00:00, 58.60it/s]
# Combination 2 by 2
# 231it [00:02, 104.41it/s]
# Combination 3 by 3
# 1540it [00:16, 91.42it/s]

# %%
support
# Out:
# {'Maaza small': 0.022686025408348458,
#  'Oreo milkshake': 0.03221415607985481,
#  'Cold coffee': 0.044918330308529944,
#  'Watermelon Juice': 0.18647912885662432,
#  'Chicken popcorn': 0.04582577132486389,
#  'Chicken wrap': 0.03312159709618875,
#  'Veg sandwich': 0.02676950998185118,
#  'Elaneer payasam': 0.022686025408348458,
#  'Crispy chicken burger': 0.024047186932849365,
#  'Veg Maagi': 0.024500907441016333,
#  'Peri Peri French Fries': 0.029491833030852996,
#  'Lemon juice': 0.06261343012704174,
#  'Coco cola': 0.023139745916515426,
#  'Muskmelon Juice': 0.06760435571687841,
#  'Bread omlette': 0.03765880217785844,
#  'Musambi juice': 0.0794010889292196,
#  'Chocolate milkshake': 0.025408348457350273,
#  'Chicken nuggets': 0.03130671506352087,
#  'Sprite': 0.025408348457350273,
#  'Cold boost': 0.02132486388384755,
#  'Rose milk': 0.02132486388384755,
#  'Crispy chicken sandwich': 0.023139745916515426}
